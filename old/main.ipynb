# %%
from binance import plot_daily_prices
from backtest import backtest

# %%
plot_daily_prices(['BTC'])

# %%
backtest(start_date='2018-01-01', amount=10)
# Out:
# 5
# ['BTC/USDT', 'ETH/USDT', 'BNB/USDT', 'NEO/USDT', 'LTC/USDT']
# 3
# ['BTC/USDT', 'ETH/USDT', 'BNB/USDT']

# %%
for year in [2018, 2019, 2020, 2021, 2022, 2023]:
    print(f'Year: {year}')
    backtest(start_date=f'{year}-01-01', end_date=f'{year}-12-31', amount=10)
# Out:
# Year: 2018
# 5
# ['BTC/USDT', 'ETH/USDT', 'BNB/USDT', 'NEO/USDT', 'LTC/USDT']
# 3
# ['BTC/USDT', 'ETH/USDT', 'BNB/USDT']
# Year: 2019
# 20
# ['BTC/USDT', 'ETH/USDT', 'BNB/USDT', 'NEO/USDT', 'LTC/USDT', 'QTUM/USDT', 'ADA/USDT', 'XRP/USDT', 'EOS/USDT', 'TUSD/USDT', 'IOTA/USDT', 'XLM/USDT', 'ONT/USDT', 'TRX/USDT', 'ETC/USDT', 'ICX/USDT', 'NULS/USDT', 'VET/USDT', 'USDC/USDT', 'LINK/USDT']
# 3
# ['BTC/USDT', 'ETH/USDT', 'BNB/USDT']
# Year: 2020
